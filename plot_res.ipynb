# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

colors = sns.color_palette("tab10")

# %% [markdown]
# # Hydrogen

# %%
H2_50 = np.array([10134476434058, 8715727146582, 302163614894, 267402005934, 254061616754, 558354851496])
H2_100 = np.array([23756679740822, 17169260922146, 450117916330, 450561598598, 514393952386, 1158344702628])
H2_200 = np.array([51316236673082, 36990622498072, 1243605496466, 1114613230262, 1058896775912, 274222809830])

exact_H2 =  2 * 11994**3

factor = np.array([0.7, 1, 1.5, 2, 2.5, 3])

N = np.array([50, 100, 200])

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)


x_ticks0 = factor * N[0]
x_ticks_labels = [f"{x:.1f}" for x in factor]
axes[0].plot(x_ticks0, H2_50 / 1e12, marker='o', label='N=50', color=colors[0])
axes[0].plot(x_ticks0, [exact_H2 / 1e12]*len(x_ticks0), linestyle='--', label='Exact', color='black')
axes[0].set_yscale('log')
axes[0].set_xlabel('Naux / N')
axes[0].set_title('N=50')
axes[0].set_xticks(x_ticks0, labels=x_ticks_labels)

x_ticks1 = factor * N[1]
axes[1].plot(x_ticks1, H2_100 / 1e12, marker='^', label='N=100', color=colors[1])
axes[1].plot(x_ticks1, [exact_H2 / 1e12]*len(x_ticks1), linestyle='--', label='Exact', color='black')
axes[1].set_yscale('log')
axes[1].set_xlabel('Naux / N')
axes[1].set_title('N=100')
axes[1].set_xticks(x_ticks1, labels=x_ticks_labels)

x_ticks2 = factor * N[2]
axes[2].plot(x_ticks2, H2_200 / 1e12, marker='x', label='N=200', color=colors[2])
axes[2].plot(x_ticks2, [exact_H2 / 1e12]*len(x_ticks2), linestyle='--', label='Exact', color='black')
axes[2].set_yscale('log')
axes[2].set_xlabel('Naux / N')
axes[2].set_title('N=200')
axes[2].set_xticks(x_ticks2, labels=x_ticks_labels)

axes[0].set_ylabel(r'Flops ($\times 1e12$)')
plt.tight_layout()

# %% [markdown]
# # Formaldehyde

# %%
factor = np.array([0.7, 1, 1.5, 2, 2.5, 3])

formaldehyde_50 = np.array([688256345911013, 710641783500873, 63019505592433, 16242097824685, 13368249830289, 18965919642037])
formaldehyde_100 = np.array([907127583220174,  1007127583220174, 1307127583220174, 22348217655421, 21934551468586, 20214942741175])
formaldehyde_200 = np.array([2051833170341421, 4051833170341421, 5051833170341421, 33487479213871, 37366877152400, 33201057403130])

exact_formaldehyde =  20 * 27643**3

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)
x_ticks0 = factor * N[0]
x_ticks_labels = [f"{x:.1f}" for x in factor]
axes[0].plot(x_ticks0, formaldehyde_50 / 1e12, marker='o', label='N=50', color=colors[0])
axes[0].plot(x_ticks0, [exact_formaldehyde / 1e12]*len(x_ticks0), linestyle='--', label='Exact', color='black')
axes[0].set_yscale('log')
axes[0].set_xlabel('Naux / N')
axes[0].set_title('N=50')
axes[0].set_xticks(x_ticks0, labels=x_ticks_labels) 

x_ticks1 = factor * N[1]
axes[1].plot(x_ticks1, formaldehyde_100 / 1e12, marker='^', label='N=100', color=colors[1])
axes[1].plot(x_ticks1, [exact_formaldehyde / 1e12]*len(x_ticks1), linestyle='--', label='Exact', color='black')
axes[1].set_yscale('log')
axes[1].set_xlabel('Naux / N')
axes[1].set_title('N=100')
axes[1].set_xticks(x_ticks1, labels=x_ticks_labels) 

x_ticks2 = factor * N[2]
axes[2].plot(x_ticks2, formaldehyde_200 / 1e12, marker='x', label='N=200', color=colors[2])
axes[2].plot(x_ticks2, [exact_formaldehyde / 1e12]*len(x_ticks2), linestyle='--', label='Exact', color='black')
axes[2].set_yscale('log')
axes[2].set_xlabel('Naux / N')
axes[2].set_title('N=200')
axes[2].set_xticks(x_ticks2, labels=x_ticks_labels)     

axes[0].set_ylabel(r'Flops ($\times 1e12$)')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Uracil

# %%
factor = np.array([2, 2.5, 3])

uracil_50 = np.array([65120821799872, 64742985385200, 62637474127816])
uracil_100 = np.array([129702789242208, 107502332028348, 118489161560116])
uracil_200 = np.array([222380426437532, 204135073174668, 224431724362668])

exact_uracil = 20 * 32416**3

fig, axes = plt.subplots(1, 3, figsize=(15, 4), sharey=True)
x_ticks0 = factor * N[0]
x_ticks_labels = [f"{x:.1f}" for x in factor]
axes[0].plot(x_ticks0, uracil_50 / 1e12, marker='o', label='N=50', color=colors[0])
axes[0].plot(x_ticks0, [exact_uracil / 1e12]*len(x_ticks0), linestyle='--', label='Exact', color='black')
axes[0].set_yscale('log')
axes[0].set_xlabel('Naux / N')
axes[0].set_title('N=50')
axes[0].set_xticks(x_ticks0, labels=x_ticks_labels)

x_ticks1 = factor * N[1]    
axes[1].plot(x_ticks1, uracil_100 / 1e12, marker='^', label='N=100', color=colors[1])
axes[1].plot(x_ticks1, [exact_uracil / 1e12]*len(x_ticks1), linestyle='--', label='Exact', color='black')
axes[1].set_yscale('log')
axes[1].set_xlabel('Naux / N')
axes[1].set_title('N=100')
axes[1].set_xticks(x_ticks1, labels=x_ticks_labels)

x_ticks2 = factor * N[2]
axes[2].plot(x_ticks2, uracil_200 / 1e12, marker='x', label='N=200', color=colors[2])
axes[2].plot(x_ticks2, [exact_uracil / 1e12]*len(x_ticks2), linestyle='--', label='Exact', color='black')
axes[2].set_yscale('log')
axes[2].set_xlabel('Naux / N')
axes[2].set_title('N=200')
axes[2].set_xticks(x_ticks2, labels=x_ticks_labels)
axes[0].set_ylabel(r'Flops ($\times 1e12$)')
plt.tight_layout()
plt.show()
